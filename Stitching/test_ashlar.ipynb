# %%
from matplotlib import pyplot as plt
import numpy as np
from make_file_scheme import *
from pathlib import Path
from PIL import Image
import numpy as np
import ashlar
# %matplotlib inline

# %%
def make_fileseries_string(input_path, overlap=0.0, pixel_size=0.0949, width=5, height=4, layout="snake", direction="horizontal"):
    input_path=Path(input_path)
    parent_path,block_folder = os.path.split(input_path)
    grandparent, location_folder = os.path.split(parent_path)
    location = location_folder
    block = block_folder[-1]

    pattern = "MAX_ch{channel:1}-"+location+"_block"+block+"_tile{series:2}.tif"
    
    fileseries_string = f"fileseries|{input_path}|pattern={pattern}|overlap={overlap}|pixel_size={pixel_size}|width={width}|height={height}|layout={layout}|direction={direction}"
    #print(fileseries_string)
    #construct command i.e. ashlar "fileseries|/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/MRC-5_MAX_SUM_PROJ/20250328_rep05/test_stitching/r02c01/Block_A|pattern=MAX_ch{channel}-r02c01_blockA_tile{series}.tif|overlap=0.1|pixel_size=0.0949|width=5|height=4|layout=snake|direction=horizontal"
    return fileseries_string

def make_output_filepath(input_path):
    input_path=Path(input_path)
    output_path = os.path.join(input_path,"ashalr_img")
    os.makedirs(output_path, exist_ok=True)
    
    parent_path,block_folder = os.path.split(input_path)
    grandparent, location_folder = os.path.split(parent_path)
    location = location_folder
    block = block_folder[-1]
    
    output_file = os.path.join(output_path, location + "_block"+block+".ome.tif")
    #print(output_file)
    return output_file

#note: can also do ashlar Index.idx.xml --plates on raw data from Opera

# %% [markdown]
# ## To preview a slide:
# ```python
# preview_slide = f"preview_slide \"{fileseries_string}\""
# !{preview_slide}
# ```
#
# ## Now make the command

# %%
def make_ashlar_command(input_path,registration_channel=0):
    fileseries_string = make_fileseries_string(input_path)
    output_file = make_output_filepath(input_path)
    
    ashlar_command = f"ashlar \"{fileseries_string}\" -c {registration_channel} -o {output_file}"
    #print(ashlar_command)
    return ashlar_command

# %% [markdown]
# # Run ashlar

# %%
test_parent_dir = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset"
for root, dirs, files in os.walk(test_parent_dir):
    for dir in dirs:
        if "Block" in dir:
            input_path = os.path.join(root, dir)
            output_path = os.path.join(input_path, "ashalr_img")
            if os.path.exists(output_path):
                print(f"Skipping {input_path}, output directory already exists.")
                continue
            else:
                registration_channel = 3 #zero-indexed to nuclei channel
                print("Processing:", input_path)
                ashlar_command = make_ashlar_command(input_path, registration_channel)
                # !{ashlar_command}
                print("Done with", input_path)
# Out:
# Processing: /mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset/R7/test_stitching/r04c03/Block_B
# Stitching and registering input images
# Cycle 0:
#     reading fileseries|/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset/R7/test_stitching/r04c03/Block_B|pattern=MAX_ch{channel:1}-r04c03_blockB_tile{series:2}.tif|overlap=0.0|pixel_size=0.0949|width=5|height=4|layout=snake|direction=horizontal
# WARNING: No tiles overlap, attempting alignment anyway.
# /opt/miniconda3/envs/ashlar/lib/python3.12/site-packages/ashlar/fileseries.py:49: FutureWarning: The plugin infrastructure in `skimage.io` is deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not pass additional keyword arguments for plugins (`**plugin_args`). Instead, use `imageio` or other I/O packages directly. See also `skimage.io.imread`.
#   img = skimage.io.imread(path, **kwargs)
# ...

# %%
input_path = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset/R5/test_stitching/r06c01/Block_A/"
registration_channel = 3 #zero-indexed

ashlar_command = make_ashlar_command(input_path, registration_channel)
print(ashlar_command)
#!{ashlar_command}
# Out:
# ashlar "fileseries|/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset/R5/test_stitching/r06c01/Block_A|pattern=MAX_ch{channel:1}-r06c01_blockA_tile{series:2}.tif|overlap=0.0|pixel_size=0.0949|width=5|height=4|layout=snake|direction=horizontal" -c 3 -o /mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/stitching/segmentation_testset/R5/test_stitching/r06c01/Block_A/ashalr_img/r06c01_blockA.ome.tif
