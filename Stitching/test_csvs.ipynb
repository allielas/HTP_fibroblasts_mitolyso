# %%
#Imports
import os
import numpy as np
import pandas as pd
#plotting
import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#import joypy
import scipy
from scipy import stats

from helpers import *

# %%
test_csv_1 = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/CP_Output/Apr10_2025/Apr10_test/new_masks/Cell.csv"
test_csv_2 = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/CP_Output/Apr10_2025/Apr10_test/Old_masks/Cell.csv"

cell_new = pd.read_csv(test_csv_1)
cell_old = pd.read_csv(test_csv_2)

#cell_v1.head()
clipped_new = cell_new.loc[cell_new['FileName_DAPI'] == "SUM_ch4-r05c05f01.tif"]
clipped_old = cell_old.loc[cell_old['FileName_DAPI'] == "SUM_ch4-r05c05f01.tif"]

clipped_new = clipped_new[["Metadata_Field","ObjectNumber","Children_Lysosomes_Count","Children_Mitochondria_Count","AreaShape_Area.1"]]
clipped_old = clipped_old[["Metadata_Field","ObjectNumber","Children_Lysosomes_Count","Children_Mitochondria_Count","AreaShape_Area.1"]]

display(clipped_new,clipped_old)
# Out:
#    Metadata_Field  ObjectNumber  Children_Lysosomes_Count  \
# 0               1             1                       224
# 1               1             2                       391
# 2               1             3                        76
# 3               1             4                       243
# 4               1             5                       144
# 5               1             6                       454
# 6               1             7                       782
# 7               1             8                       340
# 8               1             9                       476
#
#    Children_Mitochondria_Count  AreaShape_Area.1
# 0                          130             69804
# 1                          192            107167
# 2                           69             43200
# 3                          136             99020
# 4                           49             65540
# 5                          300            240280
# ...

# %%
test_csv_1 = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/CP_Output/Mar28_2025/v1/Cell.csv"
test_csv_2 = "/mnt/bigdisk1/AllieSpangaro/Morphology_Replicative_Age_Project/CP_Output/Mar28_2025/test4/Cell.csv"

cell_v1 = pd.read_csv(test_csv_1)
cell_old = pd.read_csv(test_csv_2)

#cell_v1.head()
clipped_v1 = cell_v1.loc[cell_v1['FileName_DAPI'] == "SUM_ch4-r02c02f20.tif"]
cell_v1.loc
clipped_old = cell_old.loc[cell_old['FileName_DAPI'] == "SUM_ch4-r02c02f20.tif"]


display(clipped_v1,clipped_old)
# Out:
#      ImageNumber  ObjectNumber  Metadata_CellSizeFlag  Metadata_ChannelNumber  \
# 129           60             1                      0                     NaN
#
#      Metadata_EmptyImage_Cells  Metadata_EmptyImage_Nuclei  Metadata_Field  \
# 129                          0                           0             NaN
#
#      Metadata_FileLocation  Metadata_Frame  Metadata_Series  ...  \
# 129                    NaN               0                0  ...
#
#      Texture_Variance_RescaleIntensityDAPI_3_02_256  \
# 129                                      364.797317
#
#      Texture_Variance_RescaleIntensityDAPI_3_03_256  \
# 129                                      367.649317
#
#      Texture_Variance_RescaleIntensityLAMP1_3_00_256  \
# 129                                       163.759259
#
#     Texture_Variance_RescaleIntensityLAMP1_3_01_256  \
# 129                                      164.902443
#
#     Texture_Variance_RescaleIntensityLAMP1_3_02_256  \
# ...
